# %%
import pandas as pd
file_path_app = '/Users/yifengluo/Downloads/xG-project-code-main/xG-project-code/data_cleaning/web-scraping/argentina_player_stats_pt.csv'
df_ap = pd.read_csv(file_path_app)
print(df_ap.head())
# Out:
#              Player   #       Pos     Age                  Club  Min  Gls  \
# 0            Player   #       Pos     Age                  Club  Min  Gls
# 1    Julián Álvarez   9        FW  22-321  1.engManchester City  102    0
# 2  Lautaro Martínez  22        FW  25-118             1.itInter   18    0
# 3    Ángel Di María  11        LW  34-307          1.itJuventus   63    1
# 4      Marcos Acuña   8  LW,CM,LM  31-051           1.esSevilla   57    0
#
#    Ast  PK  PKatt  ...  SoT  CrdY  CrdR  Touches  Tkl  Int  Blocks   xG  npxG  \
# 0  Ast  PK  PKatt  ...  SoT  CrdY  CrdR  Touches  Tkl  Int  Blocks   xG  npxG
# 1    0   0      0  ...    1     0     0       39    0    0       1  0.1   0.1
# 2    0   0      0  ...    1     0     0       13    0    0       0  0.6   0.6
# 3    0   0      0  ...    1     0     0       43    0    1       1  0.5   0.5
# 4    0   0      0  ...    0     1     0       40    2    0       2  0.0   0.0
#
#    xAG
# 0  xAG
# 1  0.0
# 2  0.0
# 3  0.2
# 4  0.1
# ...

# %%
file_path_fpp = '/Users/yifengluo/Downloads/xG-project-code-main/xG-project-code/data_cleaning/web-scraping/france_player_stats_pt.csv'
df_fp = pd.read_csv(file_path_fpp)
print(df_fp.head())
# Out:
#             Player   #    Pos     Age           Club  Min  Gls  Ast  PK  \
# 0           Player   #    Pos     Age           Club  Min  Gls  Ast  PK
# 1   Olivier Giroud   9     FW  36-079      1.itMilan   40    0    0   0
# 2    Marcus Thuram  26  LM,LW  25-134   1.deGladbach   80    0    1   0
# 3    Kylian Mbappé  10  FW,LW  23-363  1.frParis S-G  120    3    0   2
# 4  Ousmane Dembélé  11     RW  25-217  1.esBarcelona   40    0    0   0
#
#    PKatt  ...  SoT  CrdY  CrdR  Touches  Tkl  Int  Blocks   xG  npxG  xAG
# 0  PKatt  ...  SoT  CrdY  CrdR  Touches  Tkl  Int  Blocks   xG  npxG  xAG
# 1      0  ...    0     1     0       11    1    0       0  0.0   0.0  0.0
# 2      0  ...    0     1     0       34    1    0       1  0.0   0.0  0.1
# 3      2  ...    1     0     0       43    0    0       0  1.8   0.2  0.0
# 4      0  ...    0     0     0       16    0    0       1  0.0   0.0  0.0
#
# [5 rows x 21 columns]

# %%
combined_df = pd.concat([df_ap, df_fp], ignore_index=True)
combined_df
# Out:
#                  Player    #       Pos     Age                  Club    Min  \
# 0                Player    #       Pos     Age                  Club    Min
# 1        Julián Álvarez    9        FW  22-321  1.engManchester City    102
# 2      Lautaro Martínez   22        FW  25-118             1.itInter     18
# 3        Ángel Di María   11        LW  34-307          1.itJuventus     63
# 4          Marcos Acuña    8  LW,CM,LM  31-051           1.esSevilla     57
# 5          Lionel Messi   10     RW,FW  35-177         1.frParis S-G    120
# 6   Alexis Mac Allister   20        LM  23-359         1.engBrighton    115
# 7       Germán Pezzella    6        CB  31-174             1.esBetis      5
# 8        Enzo Fernández   24     CM,RM  21-335           1.ptBenfica    120
# 9       Rodrigo De Paul    7        RM  28-208   1.esAtlético Madrid    101
# 10      Leandro Paredes    5        CM  28-172          1.itJuventus     19
# ...

# %%
combined_df = combined_df.iloc[1:]
combined_df
# Out:
#                  Player    #       Pos     Age                  Club    Min  \
# 1        Julián Álvarez    9        FW  22-321  1.engManchester City    102
# 2      Lautaro Martínez   22        FW  25-118             1.itInter     18
# 3        Ángel Di María   11        LW  34-307          1.itJuventus     63
# 4          Marcos Acuña    8  LW,CM,LM  31-051           1.esSevilla     57
# 5          Lionel Messi   10     RW,FW  35-177         1.frParis S-G    120
# 6   Alexis Mac Allister   20        LM  23-359         1.engBrighton    115
# 7       Germán Pezzella    6        CB  31-174             1.esBetis      5
# 8        Enzo Fernández   24     CM,RM  21-335           1.ptBenfica    120
# 9       Rodrigo De Paul    7        RM  28-208   1.esAtlético Madrid    101
# 10      Leandro Paredes    5        CM  28-172          1.itJuventus     19
# 11   Nicolás Tagliafico    3        LB  30-109              1.frLyon    119
# ...
